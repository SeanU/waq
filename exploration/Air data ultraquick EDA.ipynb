# %%
import pandas as pd

# %%
# !pwd
# Out:
# /Users/ninakuklisova/Documents/MIDS/W 210 Capstone

# %% [markdown]
# Importing all the files with hourly data available on the EPA website.

# %%
no_files = ("42101", "42401", "42602", "44201", "81102", "88502", "HAPS", "LEAD", "NoNOxNOy", "SPEC", "VOCS")

for i in no_files:
    path = "Hourly_data/Hourly_%s_2016.csv" %i
    print path
    frame = pd.read_csv(path, 
                            #index_col = 0, 
                            delimiter = ',', 
                            dayfirst = True, 
                            parse_dates = [0])
    #frame['Date']= Date
    print frame.size
    dataset = pd.concat([dataset, frame])
    print dataset.size
# Out:
# Hourly_data/Hourly_42101_2016.csv
# 11261928
# 22523856
# Hourly_data/Hourly_42401_2016.csv
# 20441064
# 42964920
# Hourly_data/Hourly_42602_2016.csv
# 17300760
# 60265680
# Hourly_data/Hourly_44201_2016.csv
# 40265400
# 100531080
# Hourly_data/Hourly_81102_2016.csv
# 11747016
# 112278096
# Hourly_data/Hourly_88502_2016.csv
# 15320736
# 127598832
# Hourly_data/Hourly_HAPS_2016.csv
# 872376
# 128471208
# Hourly_data/Hourly_LEAD_2016.csv
# 0
# 128471208
# Hourly_data/Hourly_NoNOxNOy_2016.csv
# 39093576
# 167564784
# Hourly_data/Hourly_SPEC_2016.csv
# 1237920
# 168802704
# Hourly_data/Hourly_VOCS_2016.csv
# 24292248
# 193094952

# %% [markdown]
# Just in case it could help, removing duplicates.

# %%
dataset.drop_duplicates()
# Out:
#         State Code  County Code  Site Num  Parameter Code   POC   Latitude  \
# 0               01         73.0      23.0         42101.0   2.0  33.553056
# 1               01         73.0      23.0         42101.0   2.0  33.553056
# 2               01         73.0      23.0         42101.0   2.0  33.553056
# 3               01         73.0      23.0         42101.0   2.0  33.553056
# 4               01         73.0      23.0         42101.0   2.0  33.553056
# 5               01         73.0      23.0         42101.0   2.0  33.553056
# 6               01         73.0      23.0         42101.0   2.0  33.553056
# 7               01         73.0      23.0         42101.0   2.0  33.553056
# 8               01         73.0      23.0         42101.0   2.0  33.553056
# 9               01         73.0      23.0         42101.0   2.0  33.553056
# 10              01         73.0      23.0         42101.0   2.0  33.553056
# ...

# %%
dataset.columns
# Out:
# Index([u'State Code', u'County Code', u'Site Num', u'Parameter Code', u'POC',
#        u'Latitude', u'Longitude', u'Datum', u'Parameter Name', u'Date Local',
#        u'Time Local', u'Date GMT', u'Time GMT', u'Sample Measurement',
#        u'Units of Measure', u'MDL', u'Uncertainty', u'Qualifier',
#        u'Method Type', u'Method Code', u'Method Name', u'State Name',
#        u'County Name', u'Date of Last Change'],
#       dtype='object')

# %%
% matplotlib inline

import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.basemap import Basemap
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-7-7b34900c5ec5> in <module>()
#       3 import matplotlib.pyplot as plt
#       4 import numpy as np
# ----> 5 from mpl_toolkits.basemap import Basemap
#
# ImportError: No module named basemap
