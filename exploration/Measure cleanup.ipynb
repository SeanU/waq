# %%
import pandas as pd
import csv

pd.options.display.max_columns = None

# %% [markdown]
# # Importing measure translation list

# %%
measures = pd.read_csv('../data/measure-rosetta-nomicrobes.txt',
                       sep='|')
measures
# Out:
#                                                Measure  \
# 0                                1,1,1-Trichloroethane
# 1                                1,1,2-Trichloroethane
# 2                                 1,1-Dichloroethylene
# 3                               1,2,4-Trichlorobenzene
# 4                          1,2-Dibromo-3-chloropropane
# 5                                   1,2-Dichloroethane
# 6                                  1,2-Dichloropropane
# 7             2,2',3,3',4,4',5,5',6-Nonachlorobiphenyl
# 8               2,2',3,3',4,4',5,5'-Octachlorobiphenyl
# 9               2,2',3,3',4,4',5,6'-Octachlorobiphenyl
# 10            2,2',3,3',4,4',5,6,6'-Nonachlorobiphenyl
# 11               2,2',3,3',4,4',5,6-Octachlorobiphenyl
# 12                2,2',3,3',4,4',5-Heptachlorobiphenyl
# 13                   2,2',3,3',4,4'-Hexachlorobiphenyl
# 14               2,2',3,3',4,5',6'-Heptachlorobiphenyl
# 15              2,2',3,3',4,5',6,6'-Octachlorobiphenyl
# 16                   2,2',3,3',4,5'-Hexachlorobiphenyl
# 17               2,2',3,3',4,5,5',6-Octachlorobiphenyl
# 18                2,2',3,3',4,5,5'-Heptachlorobiphenyl
# 19                2,2',3,3',4,5,6'-Heptachlorobiphenyl
# 20               2,2',3,3',4,5,6,6'-Octachlorobiphenyl
# 21                   2,2',3,3',4,6'-Hexachlorobiphenyl
# 22                2,2',3,3',4,6,6'-Heptachlorobiphenyl
# 23                    2,2',3,3',4,6-Hexachlorobiphenyl
# 24                     2,2',3,3',4-Pentachlorobiphenyl
# 25                2,2',3,3',5,5',6-Heptachlorobiphenyl
# 26                   2,2',3,3',5,5'-Hexachlorobiphenyl
# 27                   2,2',3,3',6,6'-Hexachlorobiphenyl
# 28                     2,2',3,3',6-Pentachlorobiphenyl
# 29                   2,2',3,4',5',6-Hexachlorobiphenyl
# ..                                                 ...
# 284                                            Styrene
# 285                                Tetrachloroethylene
# 286                                           Thallium
# 287                                            Toluene
# 288                           Total Dichloro Biphenyls
# 289                        Total Heptachloro Biphenyls
# 290                         Total Hexachloro Biphenyls
# 291                        Total Pentachloro Biphenyls
# 292                          Total Trichloro Biphenyls
# 293                                          Toxaphene
# 294                                    Tribromomethane
# 295                                  Trichloroethylene
# 296                                          Turbidity
# 297                                 Turbidity severity
# 298                                 Turbidity, hellige
# 299                                     Vinyl chloride
# 300                                             Xylene
# 301                           Xylenes mix of m + o + p
# 302                               Xylenes, m- & p- Mix
# 303                           cis-1,2-Dichloroethylene
# 304                                         m,p-Xylene
# 305                                           m-Xylene
# 306                             meta & para Xylene mix
# 307                                  o-Dichlorobenzene
# 308                                           o-Xylene
# 309         o-Xylene, mixt. with m-xylene and p-xylene
# 310                                  p-Dichlorobenzene
# 311                                           p-Xylene
# 312  trans-1,2-Dichloroethene***retired***use trans...
# 313                         trans-1,2-Dichloroethylene
#
#                                                  Limit  \
# 0                                              .2 mg/L
# 1                                            .005 mg/L
# 2                                            .007 mg/L
# 3                                             .07 mg/L
# 4                                           .0002 mg/L
# 5                                            .005 mg/L
# 6                                            .005 mg/L
# 7                                           .0005 mg/L
# 8                                           .0005 mg/L
# 9                                           .0005 mg/L
# 10                                          .0005 mg/L
# 11                                          .0005 mg/L
# 12                                          .0005 mg/L
# 13                                          .0005 mg/L
# 14                                          .0005 mg/L
# 15                                          .0005 mg/L
# 16                                          .0005 mg/L
# 17                                          .0005 mg/L
# 18                                          .0005 mg/L
# 19                                          .0005 mg/L
# 20                                          .0005 mg/L
# 21                                          .0005 mg/L
# 22                                          .0005 mg/L
# 23                                          .0005 mg/L
# 24                                          .0005 mg/L
# 25                                          .0005 mg/L
# 26                                          .0005 mg/L
# 27                                          .0005 mg/L
# 28                                          .0005 mg/L
# 29                                          .0005 mg/L
# ..                                                 ...
# 284                                            .1 mg/L
# 285                                          .005 mg/L
# 286                                          .002 mg/L
# 287                                             1 mg/L
# 288                                         .0005 mg/L
# 289                                         .0005 mg/L
# 290                                         .0005 mg/L
# 291                                         .0005 mg/L
# 292                                         .0005 mg/L
# 293                                          .003 mg/L
# 294                                          .080 mg/L
# 295                                          .005 mg/L
# 296  1 NTU, 0.3 NTU in 95% of samples, 5NTU for non...
# 297  1 NTU, 0.3 NTU in 95% of samples, 5NTU for non...
# 298  1 NTU, 0.3 NTU in 95% of samples, 5NTU for non...
# 299                                          .002 mg/L
# 300                                                 10
# 301                                                 10
# 302                                                 10
# 303                                           .07 mg/L
# 304                                                 10
# 305                                                 10
# 306                                                 10
# 307                                            .6 mg/L
# 308                                                 10
# 309                                                 10
# 310                                          .075 mg/L
# 311                                                 10
# 312                                            .1 mg/L
# 313                                            .1 mg/L
#
#                      MeasureGroup
# 0          1,1,1-Trichloroethane
# 1          1,1,2-Trichloroethane
# 2           1,1-Dichloroethylene
# 3         1,2,4-Trichlorobenzene
# 4    1,2-Dibromo-3-chloropropane
# 5             1,2-Dichloroethane
# 6            1,2-Dichloropropane
# 7                            PCBs
# 8                            PCBs
# 9                            PCBs
# 10                           PCBs
# 11                           PCBs
# 12                           PCBs
# 13                           PCBs
# 14                           PCBs
# 15                           PCBs
# 16                           PCBs
# 17                           PCBs
# 18                           PCBs
# 19                           PCBs
# 20                           PCBs
# 21                           PCBs
# 22                           PCBs
# 23                           PCBs
# 24                           PCBs
# 25                           PCBs
# 26                           PCBs
# 27                           PCBs
# 28                           PCBs
# 29                           PCBs
# ..                            ...
# 284                      Styrene
# 285          Tetrachloroethylene
# 286                     Thallium
# 287                      Toluene
# 288                          PCBs
# 289                          PCBs
# 290                          PCBs
# 291                          PCBs
# 292                          PCBs
# 293                    Toxaphene
# 294                         TTHMs
# 295            Trichloroethylene
# 296                     Turbidity
# 297                     Turbidity
# 298                     Turbidity
# 299               Vinyl chloride
# 300                        xylene
# 301                        xylene
# 302                        xylene
# 303     cis-1,2-Dichloroethylene
# 304                        xylene
# 305                        xylene
# 306                        xylene
# 307            o-Dichlorobenzene
# 308                        xylene
# 309                        xylene
# 310            p-Dichlorobenzene
# 311                        xylene
# 312   trans-1,2-Dichloroethylene
# 313   trans-1,2-Dichloroethylene
#
# [314 rows x 3 columns]

# %% [markdown]
# # County Codes

# %%
counties = pd.read_csv('../data/ca_county_codes.csv',
                      names=['State', 'StateCode', 'CountyCode', 'CountyName', 'Class'])

counties
# Out:
#    State  StateCode  CountyCode              CountyName Class
# 0     CA          6           1          Alameda County    H1
# 1     CA          6           3           Alpine County    H1
# 2     CA          6           5           Amador County    H1
# 3     CA          6           7            Butte County    H1
# 4     CA          6           9        Calaveras County    H1
# 5     CA          6          11           Colusa County    H1
# 6     CA          6          13     Contra Costa County    H1
# 7     CA          6          15        Del Norte County    H1
# 8     CA          6          17        El Dorado County    H1
# 9     CA          6          19           Fresno County    H1
# 10    CA          6          21            Glenn County    H1
# 11    CA          6          23         Humboldt County    H1
# 12    CA          6          25         Imperial County    H1
# 13    CA          6          27             Inyo County    H1
# 14    CA          6          29             Kern County    H1
# 15    CA          6          31            Kings County    H1
# 16    CA          6          33             Lake County    H1
# 17    CA          6          35           Lassen County    H1
# 18    CA          6          37      Los Angeles County    H1
# 19    CA          6          39           Madera County    H1
# 20    CA          6          41            Marin County    H1
# 21    CA          6          43         Mariposa County    H1
# 22    CA          6          45        Mendocino County    H1
# 23    CA          6          47           Merced County    H1
# 24    CA          6          49            Modoc County    H1
# 25    CA          6          51             Mono County    H1
# 26    CA          6          53         Monterey County    H1
# 27    CA          6          55             Napa County    H1
# 28    CA          6          57           Nevada County    H1
# 29    CA          6          59           Orange County    H1
# 30    CA          6          61           Placer County    H1
# 31    CA          6          63           Plumas County    H1
# 32    CA          6          65        Riverside County    H1
# 33    CA          6          67       Sacramento County    H1
# 34    CA          6          69       San Benito County    H1
# 35    CA          6          71   San Bernardino County    H1
# 36    CA          6          73        San Diego County    H1
# 37    CA          6          75    San Francisco County    H6
# 38    CA          6          77      San Joaquin County    H1
# 39    CA          6          79  San Luis Obispo County    H1
# 40    CA          6          81        San Mateo County    H1
# 41    CA          6          83    Santa Barbara County    H1
# 42    CA          6          85      Santa Clara County    H1
# 43    CA          6          87       Santa Cruz County    H1
# 44    CA          6          89           Shasta County    H1
# 45    CA          6          91           Sierra County    H1
# 46    CA          6          93         Siskiyou County    H1
# 47    CA          6          95           Solano County    H1
# 48    CA          6          97           Sonoma County    H1
# 49    CA          6          99       Stanislaus County    H1
# 50    CA          6         101           Sutter County    H1
# 51    CA          6         103           Tehama County    H1
# 52    CA          6         105          Trinity County    H1
# 53    CA          6         107           Tulare County    H1
# 54    CA          6         109         Tuolumne County    H1
# 55    CA          6         111          Ventura County    H1
# 56    CA          6         113             Yolo County    H1
# 57    CA          6         115             Yuba County    H1

# %% [markdown]
# # Loading station data

# %%
station = pd.read_csv('../data/station-clean.csv.bz2',
                     usecols=['MonitoringLocationIdentifier', 
                              'LatitudeMeasure', 
                              'LongitudeMeasure',
                              'CountyCode'])
station
# Out:
#        MonitoringLocationIdentifier  LatitudeMeasure  LongitudeMeasure  \
# 0              USBR-324903114320201        32.817711       -114.534672
# 1                     USGS-09423500        34.851671       -114.609965
# 2                     USGS-09424150        34.316126       -114.157170
# 3                     USGS-09424170        34.300015       -114.163281
# 4                     USGS-09427500        34.316126       -114.157170
# 5                     USGS-09427520        34.295570       -114.140225
# 6                     USGS-09427524        34.295570       -114.140225
# 7                     USGS-09427600        34.291681       -114.157725
# 8                     USGS-09427800        34.279182       -114.148003
# 9                     USGS-09428000        34.258348       -114.150780
# 10                    USGS-09428200        34.254182       -114.198004
# 11                    USGS-09428599        34.170571       -114.298840
# 12                    USGS-09429000        33.731966       -114.511900
# 13                    USGS-09429001        33.731688       -114.512733
# 14                    USGS-09429002        33.731688       -114.512733
# 15                    USGS-09429003        33.731688       -114.512733
# 16                    USGS-09429010        33.731966       -114.511900
# 17                    USGS-09429011        33.731966       -114.511900
# 18                    USGS-09429099        33.731966       -114.511900
# 19                    USGS-09429100        33.719466       -114.498011
# 20                    USGS-09429105        33.726466       -114.504344
# 21                    USGS-09429130        33.683912       -114.537734
# 22                    USGS-09429133        33.663634       -114.527177
# 23                    USGS-09429144        33.610302       -114.525788
# 24                    USGS-09429149        33.601969       -114.534677
# 25                    USGS-09429152        33.589469       -114.542455
# 26                    USGS-09429155        33.574748       -114.546344
# 27                    USGS-09429156        33.575303       -114.540232
# 28                    USGS-09429160        33.535026       -114.560510
# 29                    USGS-09429161        33.561137       -114.533288
# ...                             ...              ...               ...
# 133793         USGS-340132117214401        34.025570       -117.363101
# 133794         USGS-340843117032501        34.145288       -117.057813
# 133795         USGS-341014116494801        34.170565       -116.830859
# 133796         USGS-372206120504701        37.368271       -120.847425
# 133797         USGS-372450120423300        37.413826       -120.710200
# 133798         USGS-373059120222201        37.516325       -120.373802
# 133799         USGS-373222119371501        37.539380       -119.621822
# 133800         USGS-373637119573801        37.610211       -119.961566
# 133801         USGS-373752120343801        37.631044       -120.578255
# 133802         USGS-373901119530701        37.650209       -119.886286
# 133803         USGS-374001119483701        37.666874       -119.811284
# 133804         USGS-374017119472301        37.671318       -119.790728
# 133805         USGS-374209121103800        37.702429       -121.178272
# 133806         USGS-374419120570701        37.738540       -120.952990
# 133807         USGS-374435119335301        37.742981       -119.565719
# 133808         USGS-374442119330201        37.744925       -119.551552
# 133809         USGS-384942122105601        38.828234       -122.183307
# 133810         USGS-391426121565001        39.240445       -121.948307
# 133811         USGS-392512121524801        39.419886       -121.881086
# 133812         USGS-393503121475601        39.584052       -121.799976
# 133813         USGS-394344121420901        39.728773       -121.703586
# 133814         USGS-395336121413201        39.893216       -121.693310
# 133815         USGS-395432121370101        39.908772       -121.618030
# 133816         USGS-395627122034901        39.940714       -122.064708
# 133817         USGS-400414121421301        40.070438       -121.704702
# 133818         USGS-400516121350401        40.087660       -121.585532
# 133819         USGS-400609121294701        40.102382       -121.497473
# 133820         USGS-401116121315201        40.187659       -121.532198
# 133821                USGS-10310000        38.769628       -119.833789
# 133822                USGS-10336610        38.922408       -119.991571
#
#         CountyCode
# 0             25.0
# 1             71.0
# 2             71.0
# 3             71.0
# 4             71.0
# 5             71.0
# 6             71.0
# 7             71.0
# 8             71.0
# 9             71.0
# 10            71.0
# 11            65.0
# 12            65.0
# 13            65.0
# 14            65.0
# 15            65.0
# 16            65.0
# 17            65.0
# 18            65.0
# 19            65.0
# 20            65.0
# 21            65.0
# 22            65.0
# 23            65.0
# 24            65.0
# 25            65.0
# 26            65.0
# 27            65.0
# 28            65.0
# 29            65.0
# ...            ...
# 133793        71.0
# 133794        71.0
# 133795        71.0
# 133796        99.0
# 133797        99.0
# 133798        47.0
# 133799        43.0
# 133800        43.0
# 133801        99.0
# 133802        43.0
# 133803        43.0
# 133804        43.0
# 133805        99.0
# 133806        99.0
# 133807        43.0
# 133808        43.0
# 133809       113.0
# 133810        11.0
# 133811         7.0
# 133812         7.0
# 133813         7.0
# 133814         7.0
# 133815         7.0
# 133816       103.0
# 133817       103.0
# 133818         7.0
# 133819         7.0
# 133820       103.0
# 133821         3.0
# 133822        17.0
#
# [133823 rows x 4 columns]

# %% [markdown]
# # Loading Results

# %%
waterresults = pd.read_csv('../data/CA-result.csv.bz2',
                           usecols=['ActivityMediaName', 'ActivityMediaSubdivisionName',
                                  'ActivityStartDate', 'ActivityStartTime/Time',
                                  'ActivityStartTime/TimeZoneCode', 'ActivityEndDate',
                                  'ActivityEndTime/Time', 'ActivityEndTime/TimeZoneCode',
                                  'MonitoringLocationIdentifier', 'CharacteristicName',
                                  'ResultMeasureValue', 'ResultMeasure/MeasureUnitCode',
                                  'ResultCommentText'],
                          error_bad_lines=False)
waterresults = waterresults[waterresults.ActivityMediaName == 'Water']
waterresults["ResultMeasureValue"] = \
    pd.to_numeric(waterresults.ResultMeasureValue, errors='coerce')

waterresults.head(10)
# Out:
# /Users/Sean/anaconda/lib/python3.5/site-packages/IPython/core/interactiveshell.py:2717: DtypeWarning: Columns (33,5,9,10,11,44) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    ActivityMediaName ActivityMediaSubdivisionName ActivityStartDate  \
# 9              Water                          NaN        2009-10-10
# 10             Water                          NaN        2009-10-10
# 11             Water                          NaN        2009-10-06
# 12             Water                          NaN        2009-10-16
# 14             Water                          NaN        2009-07-12
# 15             Water                          NaN        2009-07-12
# 16             Water                          NaN        2009-07-18
# 26             Water                          NaN        2009-10-22
# 30             Water                          NaN        2009-08-11
# 31             Water                          NaN        2009-10-30
#
#    ActivityStartTime/Time ActivityStartTime/TimeZoneCode ActivityEndDate  \
# 9                00:00:00                            NaN             NaN
# 10               00:00:00                            NaN             NaN
# 11               00:00:00                            PDT             NaN
# 12               00:00:00                            PDT             NaN
# 14               00:00:00                            PDT             NaN
# 15               00:00:00                            PDT             NaN
# 16               00:00:00                            PDT             NaN
# 26               00:00:00                            PDT             NaN
# 30               00:00:00                            PDT             NaN
# 31               00:00:00                            PDT             NaN
#
#    ActivityEndTime/Time ActivityEndTime/TimeZoneCode  \
# 9                   NaN                          NaN
# 10                  NaN                          NaN
# 11                  NaN                          NaN
# 12                  NaN                          NaN
# 14                  NaN                          NaN
# 15                  NaN                          NaN
# 16                  NaN                          NaN
# 26                  NaN                          NaN
# 30                  NaN                          NaN
# 31                  NaN                          NaN
#
#     MonitoringLocationIdentifier  \
# 9   MATTOLE_SALMON-MAT_EST_6B_09
# 10  MATTOLE_SALMON-MAT_EST_6B_09
# 11            MRSENVMB_WQX-M-001
# 12            MRSENVMB_WQX-M-001
# 14            MRSENVMB_WQX-M-001
# 15            MRSENVMB_WQX-M-001
# 16            MRSENVMB_WQX-M-001
# 26            MRSENVMB_WQX-M-001
# 30            MRSENVMB_WQX-M-001
# 31            MRSENVMB_WQX-M-001
#
#                                 CharacteristicName  ResultMeasureValue  \
# 9                               Temperature, water               15.16
# 10                           Dissolved oxygen (DO)               10.06
# 11                                              pH                7.40
# 12                                       Turbidity               20.00
# 14                                  Total Coliform                4.00
# 15                                              pH                7.60
# 16                              Temperature, water               22.00
# 26                                       Turbidity               26.00
# 30  Biochemical oxygen demand, standard conditions               31.00
# 31                          Total suspended solids               15.00
#
#    ResultMeasure/MeasureUnitCode ResultCommentText
# 9                          deg C     daily average
# 10                          mg/l     daily minimum
# 11                          None               NaN
# 12                           NTU               NaN
# 14                     MPN/100ml               NaN
# 15                          None               NaN
# 16                         deg C               NaN
# 26                           NTU               NaN
# 30                          mg/l               NaN
# 31                          mg/l               NaN

# %% [markdown]
# # Join 'er up

# %%
results = pd.merge(waterresults, measures, left_on='CharacteristicName', right_on='Measure')
results = pd.merge(results, station, on='MonitoringLocationIdentifier')
results = pd.merge(results, counties, on='CountyCode')

len(results)
# Out:
# 1337122

# %% [markdown]
# # Distinct units

# %%
# String cleanup
results["Unit"] = results["ResultMeasure/MeasureUnitCode"].astype('str').str.strip()

# Nix the NaNs:
results = results.loc[pd.notnull(results.ResultMeasureValue)]

# Units that just aren't useful:

#   % recovery is the percentage of an agent that is removed.
measuresToSkip = frozenset([
        # % recovery is % of an agent that is filtered out. Not quite what we're after.
        '%', '% recovery',
        # These measure turbidity, which I'm not worrying about for now.
        'FNU', 'FTU', 'JTU', 'NTU', 'None', 'm', 'mg/l SiO2',
        # 'code' measures turbidity severity. Same there.
        'code',
        # ppm and ppb are tricky to convert to mg/l, since you need to know
        # molecular weights. Should do, but not yet.
        'ppm', 'ppb',
        # Lead-210. Not dealing with radiologicals (yet)
        'pCi/L',
        # tons/day!? what is this shit?
        'tons/day',
        # Not in the mood to deal with micromoles, either. Micromoles per what?
        'umol'
    ])

results = results.loc[~results.Unit.isin(measuresToSkip)]


# Unit mapping

# Water has a density of 1 kg/L, so mg/kg -> mg/l is a gimme:
results.loc[results.Unit == 'mg/kg', 'Unit'] = 'mg/l'
results.loc[results.Unit == 'mg/kg as N', 'Unit'] = 'mg/l'
results.loc[results.Unit == 'ug/kg', 'Unit'] = 'ug/l'

# Nitrate has an equivalent weight of 62, and everything in the data
# that is measured using ueq/L is nitrate
results.loc[results.Unit == 'ueq/L', 'ResultMeasureValue'] *= 62
results.loc[results.Unit == 'ueq/L', 'Unit'] = 'ug/l'

# Unnecessary specification:
results.loc[results.Unit == 'mg/l as N', 'Unit'] = 'mg/l'

# 1,000 picograms per nanogram
results.loc[results.Unit == 'pg/l', 'ResultMeasureValue'] *= (1/1000)
results.loc[results.Unit == 'pg/l', 'Unit'] = 'ng/l'

# 1,000 nanograms per microgram
results.loc[results.Unit == 'ng/l', 'ResultMeasureValue'] *= (1/1000)
results.loc[results.Unit == 'ng/l', 'Unit'] = 'ug/l'

# 1,000 micrograms per milligram
results.loc[results.Unit == 'ug/l', 'ResultMeasureValue'] *= (1/1000)
results.loc[results.Unit == 'ug/l', 'Unit'] = 'mg/l'

# 1,000 ppb per ppm
results.loc[results.Unit == 'ppb', 'ResultMeasureValue'] *= (1/1000)
results.loc[results.Unit == 'ppb', 'Unit'] = 'ppm'

# %%
sorted(results.Unit.unique())
# Out:
# ['fibers/l', 'mg/l']

# %%
results[results.Unit == 'ppm'].CharacteristicName.unique()
# Out:
# array([], dtype=object)

# %%
results[results.Unit == 'umol']
# Out:
# Empty DataFrame
# Columns: [ActivityMediaName, ActivityMediaSubdivisionName, ActivityStartDate, ActivityStartTime/Time, ActivityStartTime/TimeZoneCode, ActivityEndDate, ActivityEndTime/Time, ActivityEndTime/TimeZoneCode, MonitoringLocationIdentifier, CharacteristicName, ResultMeasureValue, ResultMeasure/MeasureUnitCode, ResultCommentText, Measure, Limit, MeasureGroup, LatitudeMeasure, LongitudeMeasure, CountyCode, State, StateCode, CountyName, Class, Unit]
# Index: []

# %%
#results["Unit"] = results["ResultMeasure/MeasureUnitCode"].astype('str').str.strip()

results.loc[(results.Unit == 'ueq/L') & (results.MeasureGroup == 'nitrate'), 'Unit'] = 'mg/l'

results.loc[(results.Unit == 'mg/l') & (results.MeasureGroup == 'nitrate'), 'Unit']
# Out:
# 4939       mg/l
# 4940       mg/l
# 4941       mg/l
# 4944       mg/l
# 4947       mg/l
# 4948       mg/l
# 4949       mg/l
# 4951       mg/l
# 5355       mg/l
# 5356       mg/l
# 5357       mg/l
# 5358       mg/l
# 5359       mg/l
# 5360       mg/l
# 5361       mg/l
# 5362       mg/l
# 5363       mg/l
# 5364       mg/l
# 5365       mg/l
# 5366       mg/l
# 5367       mg/l
# 5368       mg/l
# 5369       mg/l
# 5370       mg/l
# 5371       mg/l
# 5372       mg/l
# 5373       mg/l
# 5374       mg/l
# 5375       mg/l
# 5376       mg/l
#            ...
# 1336625    mg/l
# 1336652    mg/l
# 1336653    mg/l
# 1336654    mg/l
# 1336677    mg/l
# 1336678    mg/l
# 1336701    mg/l
# 1336702    mg/l
# 1336725    mg/l
# 1336726    mg/l
# 1336749    mg/l
# 1336750    mg/l
# 1336773    mg/l
# 1336774    mg/l
# 1336797    mg/l
# 1336798    mg/l
# 1336799    mg/l
# 1336822    mg/l
# 1336823    mg/l
# 1336824    mg/l
# 1336847    mg/l
# 1336848    mg/l
# 1336871    mg/l
# 1336872    mg/l
# 1336890    mg/l
# 1336902    mg/l
# 1336959    mg/l
# 1336960    mg/l
# 1337002    mg/l
# 1337003    mg/l
# Name: Unit, dtype: object

# %% [markdown]
# # Reordering columns

# %%
results = results[['MonitoringLocationIdentifier',  'CountyCode', 'CountyName', 'LatitudeMeasure', 'LongitudeMeasure',
                   'ActivityMediaName', 'ActivityMediaSubdivisionName', 
                   'ActivityStartDate', 'ActivityStartTime/Time', 'ActivityStartTime/TimeZoneCode', 
                   'ActivityEndDate', 'ActivityEndTime/Time', 'ActivityEndTime/TimeZoneCode', 
                   'Measure', 'Limit', 'MeasureGroup', 
                   'ResultMeasureValue', 'ResultMeasure/MeasureUnitCode', 'ResultCommentText']]

# %% [markdown]
# # Save to CSV

# %%
results.to_csv('../data/CA-results-join.csv.bz2', index=False, quoting=csv.QUOTE_ALL, compression='bz2')
